# %% [markdown]
# This data is from the USGS database by Koaly et al 2017. I have set up the code to import the data you need.

# %% [markdown]
# #**Importing libraries**

# %%
#Lets import our libraries like we did before
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
import pandas as pd
import scipy
from scipy.signal import argrelextrema
from google.colab import drive

drive.mount('/content/drive')

#You'll have a link show up to give an authorization code.
#Follow the link, sign in to your account again
#Copy the authorization code into the space below and press enter
# Out:
# Mounted at /content/drive

# %% [markdown]
# #**Importing our data**
#
#
# Check the path to your xlsx files

# %%
# !ls drive/MyDrive/...
# Out:
# ls: cannot access 'drive/MyDrive/...': No such file or directory

# %% [markdown]
# Run the next code cell to create all of our data- becareful if you're changing anything!
#
# The only thing you should need to change is the path!

# %%
#All our data is stored in here
# Make sure our excel file is saved on your google drive, we will have to write the path to the file, this is mine....
data = pd.read_excel('/content/drive/MyDrive/path to files')
print(data)

#Your code goes here
#decide what data you want to work with and read it in here

print ('Data Creation Complete')

# %% [markdown]
# Now let's plot the data and identify the points of interest.
#
# Perform spectral algebra to find spectral features specific to each mineral.

# %%
#Your code goes here

# %%
#Perform spectral algebra

# %%
#Compare Downsampled PanCam spectra to the Oxia Mineral Library to identify the minerals 'found'!
