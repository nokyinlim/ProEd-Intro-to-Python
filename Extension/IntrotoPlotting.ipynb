# %% [markdown]
# #**Plotting**

# %% [markdown]
# **Matplotlib** is a Python plotting package that makes it simple to create two-dimensional plots from data stored in a variety of data structures including lists, numpy arrays, and pandas dataframes.
#
# Matplotlib uses an object oriented approach to plotting. This means that plots can be built step-by-step by adding new elements to the plot.
#
# There are two primary objects associated with a matplotlib plot:
#
# **figure object:** the overall figure space that can contain one or more plots.
#
# **axis objects:** the individual plots that are rendered within the figure.
#
#
# You can think of the figure object as your plot canvas. You can think about the axis object as an individual plot.
#
# A figure can hold one or more axis objects. This structure allows you to create figures with one or more plots on them.

# %% [markdown]
# ![fig-1-plot.png](data:image/png;base64,...)

# %% [markdown]
# #**Pyplot**
#
# Pyplot provides methods that can be used to add different components to figure objects, including creating the individual plots as axis objects, also known as subplots.
#
# The pyplot module is typically imported using the alias plt as demonstrated below.
#
#
# ```
# import matplotlib.pyplot as plt
# ```

# %% [markdown]
# To create a plot using matplotlib’s object oriented approach, you first create the figure (which you can call fig) and at least one axis (which you can call ax) using the subplots() function from the pyplot module:
#
# **`fig, ax = plt.subplots()`**
#
# Notice that the fig and ax are created at the same time by setting them equal to the output of the pyplot.subplots() function. As no other arguments have been provided, the result is a figure with one plot that is empty but ready for data.
#
# You don't have to plot this way (using ax) but it can be useful!
#
# Run the codes below and alter them to test out the commands.

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots()

# %% [markdown]
# #**Change figure size**

# %%
# Resize figure
fig, ax = plt.subplots(figsize = (10, 6))

# %% [markdown]
# #**Multi Plot figures**

# %%
# Figure with two plots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize = (10, 6))

# %%
# Figure with two plots
fig, (ax1, ax2) = plt.subplots(2, 1, figsize = (10, 6))

# %% [markdown]
# #**Plotting Data**

# %%
import numpy as np
x = np.arange(0,50,2)
y = 3*x+5

# %% [markdown]
# If we want to change the **way** our data is shown on our plots.
#
# ```
# plt.plot(x data, y data, linestyle='linename', marker='markername', color='colorname', 'o', label='Data set identifier')
# ```
#
# Adding plot titles:
#
#
#
# ```
# matplotlib.pyplot.title(label, fontdict=None, loc=’location name’, pad=None, **kwargs)
# ```
#
# Adding axis titles:
#
# ```
# plt.xlabel("x label")
# plt.ylabel("y label")
# ```

# %%
#Here is an example of using some of these commands, feel free to play around with the code!
fig, ax = plt.subplots(figsize = (10, 6))
plt.plot(x,y);
plt.plot(x,y, linestyle='--', marker='o', color='cyan', label='data dots');
ax.legend();#This line generates the legend with all the labels you have defined
#Adding axis and plot titles
plt.xlabel("X data");
plt.ylabel("Y data");

# %% [markdown]
# #Here is a non exhaustive list of the python colours:

# %% [markdown]
# ![named_colors.png](data:image/png;base64,...)

# %% [markdown]
# #Here is a non exhaustive list of python markers:
#
# ![sphx_glr_marker_reference_002.webp](data:image/webp;base64,...)

# %% [markdown]
# # Have a go at plotting data and trying out the colours, labels, titles and everything else!

# %%
#Generate data

import matplotlib.pyplot as plt
import numpy as np
# if using a jupyter notebook
# %matplotlib inline

x3 = np.arange(0,4*np.pi,0.1)   # start,stop,step
y3 = np.sin(x3)

x4 = np.arange(0,4*np.pi,0.1)   # start,stop,step
y4 = np.cos(x4)

x5 = np.arange(0,4*np.pi,0.1)   # start,stop,step
y5 = 0.7*np.sin(x5)

x6 = np.arange(0,4*np.pi,0.1)   # start,stop,step
y6 = 6*np.cos(x6)

# %%
#Your code here
